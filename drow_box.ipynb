# %%
from PIL import Image
import numpy as np
def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  print(im_width, im_height) 
  #print(list(image.getdata()))
  image =image.convert('RGB')
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %%
import matplotlib.patches as patches

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

im = np.array(Image.open('screenshot2.png'), dtype=np.uint8)

# Create figure and axes

fig,ax = plt.subplots(1,figsize=(100, 100))

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((829, 564),15,27,linewidth=1,edgecolor='r',facecolor='none')
#upper x and y 882 765
#lower x and y 897 792
# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
image = Image.open('screenshot4.png')
(im_width, im_height) = image.size
print(im_width,im_height)
len(list(image.getdata()))
# Out:
# 6500 6500
# 42250000
